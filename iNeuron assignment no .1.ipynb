# %% [markdown]
# # Assignment No . = 1
#
#
#
# 1. In the below elements which of them are values or an expression? eg:-    values can be integer or string and expressions will be mathematical operators.
#
# *   =   Mathematical Operator
#
# ‘hello’          = 	 Values
#
# --87.8	    =     Values
#
# /    = 	  Mathematical Operator
#
# +	=	  Mathematical Operator
#
# 6        =        Values
#
#
#
#
#
# 2. What is the difference between string and variable?
#
#
# String    :-  Strings in python are surrounded by either single quotation marks, or double quotation marks. Ex -‘string’
#
#
# Variable :-  Variables are containers for storing data values. Ex -spam
#
#
#
# 3. Describe three different data types.
#
#
# Integer :-  Integer define as a number .There is effectively no limit to how long an integer value can be. Ex = 1,2,3,4,4,5
# Float :- Float define as a floating point number or decimal number. Ex = 0.2, 0.23 , 1.03
# Boolean :- Boolean data type has two values one True or second False . Ex= True , False
#
#
#
#
#
# 4. What is an expression made up of? What do all expressions do?
#
#
# Expression is a combination of values, variables, operators, and calls to functions. Expressions need to be evaluated. If you ask Python to print an expression, the interpreter evaluates the expression and displays the result.  All expressions evaluate (that is, reduce) to a single value.¬
#
#
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#
# ¬¬Statement:-  A statement is an instruction that the Python interpreter can execute. We have only seen the assignment statement so far. Some other     kind ofstatemets that we’ll  see shortly are while statements, for statements,
# if statements, and import statements.
#
# Expression:-  An expression is a combination of values, variables, operators, and calls to functions. Expressions need to be evaluated. If you ask Python to print an expression, the interpreter evaluates the expression and displays the result.
#
#
#
#
# 6. After running the following code, what does the variable bacon contain?
#
#
# bacon = 22
# bacon + 1
#
# The bacon variable is set to 20. The bacon + 1 expression does not reassign the value in bacon .That would need an assignment statement: bacon = bacon + 1.
#
#
#
#
# 7. What should the values of the following two terms be?
#
#
# ‘spam’ + ‘spamspam’
# ‘spam’
#
# "spam" + "spamspam"
# Output
# 'spamspamspam'
#
# "spam" * 3
# Output
# 'spamspamspam'
#
#
#
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#
#
# Egg is a variable and 100 is a interger . Variable names cannot start with a integer.
#
#
#
#
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
#
#
# Int()  - for integer , float() – floating-point number , str() - string
#
#
#
#
# 10. Why does this expression cause an error? How can you fix it?
#
#
#
# ‘i have eaten’ + 99 + ‘burritos’
# It show error because 99 is an integer and string concatenated only with other string not with integer values.
# We can write code like this –  ‘i have eaten’ + str(99) + ‘burritos’
